# %%
import pandas as pd
from pathlib import Path
import re
import numpy as np

# %% [markdown]
# ## Merging movie reviews into one dataframe

# %%
data_dir = Path("dataset/2_reviews_per_movie_raw")

dfs = [
    pd.read_csv(file).assign(movie=file.stem)
    for file in data_dir.glob("*.csv")
]

df_reviews = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ## Creating a mapping from imdb movie ids to movies in movie reviews dataset

# %%
def extract_year(title):
    match = re.search(r'\((\d{4})\)$', title)
    return match.group(1) if match else None

# %%
def extract_clean_title(title):
    return re.sub(r'\s*\(\d{4}\)$', '', title).strip()

# %%
ratings_path = Path("ml-32m/movies.csv")
df_ratings = pd.read_csv(ratings_path)

df_ratings['year'] = df_ratings['title'].apply(extract_year)
df_ratings['clean_title'] = df_ratings['title'].apply(extract_clean_title)

movie_mapping = {
    (row['clean_title'], row['year']): row['movieId']
    for _, row in df_ratings.iterrows()
}

# %% [markdown]
# ## Set movie ids to reviews, drop reviews for movies not present in imdb dataset

# %%
def split_movie_and_movie_year(movie_str):
    match = re.search(r'(\d{4})$', movie_str)
    if match:
        year = match.group(1)
        title = movie_str[:match.start()].strip()
        return title, year
    return movie_str, None

# %%
df_reviews[['clean_movie', 'movie_year']] = df_reviews['movie'].apply(
    lambda x: pd.Series(split_movie_and_movie_year(x))
)

df_reviews['movieId'] = df_reviews.apply(
    lambda row: movie_mapping.get((row['clean_movie'], row['movie_year'])), axis=1
)

df_reviews.dropna(inplace=True)

# %%
df_reviews["review"]  = df_reviews.apply(lambda row: "".join([row["title"], row["review"]]), axis=1)

# %%
df_reviews
# Out:
#                username rating  helpful  total              date  \
# 737          boognish-6     10      252    291      4 April 2006
# 738     EdwardsMovieKit      9      155    180       2 July 2006
# 739         Special-K88   Null      175    208     12 April 2002
# 740            ereinion      9       89    105      1 April 2005
# 741            bsamdahl      9       40     46  21 February 2002
# ...                 ...    ...      ...    ...               ...
# 928726        Mackiatoe      6        0     12      3 April 2015
# 928727   olivergilbert1      8        0      2      3 April 2015
# 928728    Myjoyandlight      7        0     12      3 April 2015
# 928729     BrentHankins      7        0     13      2 April 2015
# 928730           851222      8        0      5      2 April 2015
#
#                                                     title  \
# 737                The Most Underrated Film of the '90s\n
# 738      All Quality Elements of a Magnificent Movie!!!\n
# 739                     this is how you make a thriller\n
# 740                              A beguiling experience\n
# 741                             Vanity, my favorite sin\n
# ...                                                   ...
# 928726   The ending the series deserved, even if it wa...
# 928727                                         For Paul\n
# 928728      Bittersweet movie with over-the-top action!\n
# 928729   Plenty of the franchise's trademark action, p...
# 928730   Not the most furious of fast, but still an en...
#
#                                                    review  \
# 737      The Most Underrated Film of the '90s\nThe rev...
# 738      All Quality Elements of a Magnificent Movie!!...
# 739      this is how you make a thriller\nStylish, sex...
# 740      A beguiling experience\nThis is one of the mo...
# 741      Vanity, my favorite sin\nThe Devil's advocate...
# ...                                                   ...
# 928726   The ending the series deserved, even if it wa...
# 928727   For Paul\nThe latest instalment of the fast &...
# 928728   Bittersweet movie with over-the-top action!\n...
# 928729   Plenty of the franchise's trademark action, p...
# 928730   Not the most furious of fast, but still an en...
#
#                             movie           clean_movie movie_year   movieId
# 737     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 738     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 739     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 740     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 741     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# ...                           ...                   ...        ...       ...
# 928726             Furious 7 2015             Furious 7       2015  130634.0
# 928727             Furious 7 2015             Furious 7       2015  130634.0
# 928728             Furious 7 2015             Furious 7       2015  130634.0
# 928729             Furious 7 2015             Furious 7       2015  130634.0
# 928730             Furious 7 2015             Furious 7       2015  130634.0
#
# [651169 rows x 11 columns]

# %%
df_reviews["rating"] = df_reviews["rating"].apply(lambda x: int(x) if x != "Null" else np.nan)

# %%
df_reviews.dropna(inplace=True)

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 586018 entries, 737 to 928730
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   username     586018 non-null  object
#  1   rating       586018 non-null  float64
#  2   helpful      586018 non-null  int64
#  3   total        586018 non-null  int64
#  4   date         586018 non-null  object
#  5   title        586018 non-null  object
#  6   review       586018 non-null  object
#  7   movie        586018 non-null  object
#  8   clean_movie  586018 non-null  object
#  9   movie_year   586018 non-null  object
#  10  movieId      586018 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 53.7+ MB

# %% [markdown]
# ## Processing ratings

# %%
reviews_by_movie = {
    movie: group.reset_index(drop=True)
    for movie, group in df_reviews.groupby('movieId')
}

# %%
df_reviews
# Out:
#                username  rating  helpful  total              date  \
# 737          boognish-6    10.0      252    291      4 April 2006
# 738     EdwardsMovieKit     9.0      155    180       2 July 2006
# 740            ereinion     9.0       89    105      1 April 2005
# 741            bsamdahl     9.0       40     46  21 February 2002
# 742       Snoopymichele    10.0       17     18      21 July 2006
# ...                 ...     ...      ...    ...               ...
# 928726        Mackiatoe     6.0        0     12      3 April 2015
# 928727   olivergilbert1     8.0        0      2      3 April 2015
# 928728    Myjoyandlight     7.0        0     12      3 April 2015
# 928729     BrentHankins     7.0        0     13      2 April 2015
# 928730           851222     8.0        0      5      2 April 2015
#
#                                                     title  \
# 737                The Most Underrated Film of the '90s\n
# 738      All Quality Elements of a Magnificent Movie!!!\n
# 740                              A beguiling experience\n
# 741                             Vanity, my favorite sin\n
# 742                        Be careful what you wish for\n
# ...                                                   ...
# 928726   The ending the series deserved, even if it wa...
# 928727                                         For Paul\n
# 928728      Bittersweet movie with over-the-top action!\n
# 928729   Plenty of the franchise's trademark action, p...
# 928730   Not the most furious of fast, but still an en...
#
#                                                    review  \
# 737      The Most Underrated Film of the '90s\nThe rev...
# 738      All Quality Elements of a Magnificent Movie!!...
# 740      A beguiling experience\nThis is one of the mo...
# 741      Vanity, my favorite sin\nThe Devil's advocate...
# 742      Be careful what you wish for\nWhen Kevin Loma...
# ...                                                   ...
# 928726   The ending the series deserved, even if it wa...
# 928727   For Paul\nThe latest instalment of the fast &...
# 928728   Bittersweet movie with over-the-top action!\n...
# 928729   Plenty of the franchise's trademark action, p...
# 928730   Not the most furious of fast, but still an en...
#
#                             movie           clean_movie movie_year   movieId
# 737     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 738     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 740     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 741     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# 742     The Devil's Advocate 1997  The Devil's Advocate       1997    1645.0
# ...                           ...                   ...        ...       ...
# 928726             Furious 7 2015             Furious 7       2015  130634.0
# 928727             Furious 7 2015             Furious 7       2015  130634.0
# 928728             Furious 7 2015             Furious 7       2015  130634.0
# 928729             Furious 7 2015             Furious 7       2015  130634.0
# 928730             Furious 7 2015             Furious 7       2015  130634.0
#
# [586018 rows x 11 columns]

# %%
df_reviews = df_reviews[df_reviews['rating'] != "Null"].copy()
df_reviews['rating'] = pd.to_numeric(df_reviews['rating'], errors='coerce')
df_reviews = df_reviews.dropna(subset=['rating'])
df_reviews['scaled_rating'] = 0.5 + 0.5 * (df_reviews['rating'] - 1)

reviews_by_movie = {
    movie: group.reset_index(drop=True)
    for movie, group in df_reviews.groupby('movieId')
}

# %% [markdown]
# ## Assign available reviews
#
# We assign reviews to entries in our dataset of ratings in such a way that reviews are not repeated and the difference between the rating in dataset and rating in review doesnt differ in more than 2 stars out of 5 (so that there is no extreme cases such that 1 star rating has 5 star review)

# %%
def assign_reviews_unique_diff(ratings_group, reviews_group, lower_bound=0, upper_bound=1.5):
    ratings_group = ratings_group.copy()
    n_ratings = len(ratings_group)
    
    assigned_usernames = [None] * n_ratings
    assigned_reviews   = [None] * n_ratings
    assigned_raw_ratings = [None] * n_ratings
    assigned_diffs     = [None] * n_ratings

    if reviews_group is None or reviews_group.empty:
        ratings_group['review_username'] = assigned_usernames
        ratings_group['review_text'] = assigned_reviews
        ratings_group['review_raw_rating'] = assigned_raw_ratings
        ratings_group['rating_diff'] = assigned_diffs
        return ratings_group

    available = list(range(len(reviews_group)))
    
    review_scaled = reviews_group['scaled_rating'].values
    review_usernames = reviews_group['username'].values
    review_texts = reviews_group['review'].values
    review_raw_ratings = reviews_group['rating'].values

    for i, imdb_rating in enumerate(ratings_group['rating']):
        best_idx = None
        best_diff = None
        for j in available:
            diff = abs(imdb_rating - review_scaled[j])
            if lower_bound <= diff <= upper_bound:
                if best_idx is None or diff < best_diff:
                    best_idx = j
                    best_diff = diff
        if best_idx is not None:
            assigned_usernames[i] = review_usernames[best_idx]
            assigned_reviews[i] = review_texts[best_idx]
            assigned_raw_ratings[i] = review_raw_ratings[best_idx]
            assigned_diffs[i] = best_diff
            available.remove(best_idx)
            if not available:
                break

    ratings_group['review_username'] = assigned_usernames
    ratings_group['review_text'] = assigned_reviews
    ratings_group['review_raw_rating'] = assigned_raw_ratings
    ratings_group['rating_diff'] = assigned_diffs
    return ratings_group

# %%
df_ratings = pd.read_csv("ml-32m/ratings.csv")

df_ratings_with_diff_reviews = df_ratings.groupby('movieId', group_keys=False).apply(
    lambda group: assign_reviews_unique_diff(group, reviews_by_movie.get(group.name), lower_bound=0, upper_bound=2)
)
# Out:
# /var/folders/7f/gc2d7y611gn1hg8cn9hd196h0000gp/T/ipykernel_41107/1230877411.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_ratings_with_diff_reviews = df_ratings.groupby('movieId', group_keys=False).apply(
# /var/folders/7f/gc2d7y611gn1hg8cn9hd196h0000gp/T/ipykernel_41107/1230877411.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_ratings_with_diff_reviews = df_ratings.groupby('movieId', group_keys=False).apply(

# %%
df_ratings_with_diff_reviews
# Out:
#           userId  movieId  rating   timestamp review_username review_text  \
# 0              1       17     4.0   944249077            None        None
# 1              1       25     1.0   944250228            None        None
# 2              1       29     2.0   943230976            None        None
# 3              1       30     5.0   944249077            None        None
# 4              1       32     5.0   943228858            None        None
# ...          ...      ...     ...         ...             ...         ...
# 32000199  200948    79702     4.5  1294412589            None        None
# 32000200  200948    79796     1.0  1287216292            None        None
# 32000201  200948    80350     0.5  1294412671            None        None
# 32000202  200948    80463     3.5  1350423800            None        None
# 32000203  200948    87304     4.5  1350423523            None        None
#
#           review_raw_rating  rating_diff
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# ...                     ...          ...
# 32000199                NaN          NaN
# 32000200                NaN          NaN
# 32000201                NaN          NaN
# 32000202                NaN          NaN
# 32000203                NaN          NaN
#
# [32000204 rows x 8 columns]

# %%
df_ratings_with_diff_reviews[df_ratings_with_diff_reviews["rating_diff"] > 0]
# Out:
#           userId  movieId  rating   timestamp review_username  \
# 70             1     1242     1.0   943231162        harry-76
# 8839          61      595     3.0   831973763       Atreyu_II
# 10460         70      595     3.0   996496466   jessbir-23618
# 11172         73     1293     1.0  1172040582       ldlAkasha
# 11973         77      595     3.0   842069194  spencergrande6
# ...          ...      ...     ...         ...             ...
# 31966675  200724   183869     2.5  1604015287     covington_c
# 31967251  200726   143347     4.0  1604374451      bladsgaard
# 31968207  200729   200540     3.5  1572128608        rima1981
# 31987956  200861   197711     2.5  1576772827   neptunesblood
# 31987959  200861   200540     1.5  1577137136         Booga04
#
#                                                 review_text  \
# 70         Distorted Perspective\nMilitary intelligence ...
# 8839       A very popular Disney movie\nThe 30th animate...
# 10460      be our guest\nBeauty and the beast is a timel...
# 11172      historically inaccurate\nThis movie had poten...
# 11973      Plot is flimsy but the music is iconic, duh\n...
# ...                                                     ...
# 31966675   Really though!?\nUnbelievable craptacular bs....
# 31967251   One of the very best superhero movies so far!...
# 31968207   Awesome!\nIt was funny, it was sweet and all ...
# 31987956   Worst Horror Movie in a long time.\nI conside...
# 31987959   Bad.\n<ul><li>Confusing. If you hadn't seen t...
#
#           review_raw_rating  rating_diff
# 70                      3.0          0.5
# 8839                    7.0          0.5
# 10460                   7.0          0.5
# 11172                   1.0          0.5
# 11973                   7.0          0.5
# ...                     ...          ...
# 31966675                1.0          2.0
# 31967251                9.0          0.5
# 31968207                9.0          1.0
# 31987956                1.0          2.0
# 31987959                1.0          1.0
#
# [200118 rows x 8 columns]

# %%
df_ratings_with_diff_reviews.drop(columns=["timestamp", "review_username"], inplace=True)

# %%
df_ratings_with_diff_reviews
# Out:
#           userId  movieId  rating review_text  review_raw_rating  rating_diff
# 0              1       17     4.0        None                NaN          NaN
# 1              1       25     1.0        None                NaN          NaN
# 2              1       29     2.0        None                NaN          NaN
# 3              1       30     5.0        None                NaN          NaN
# 4              1       32     5.0        None                NaN          NaN
# ...          ...      ...     ...         ...                ...          ...
# 32000199  200948    79702     4.5        None                NaN          NaN
# 32000200  200948    79796     1.0        None                NaN          NaN
# 32000201  200948    80350     0.5        None                NaN          NaN
# 32000202  200948    80463     3.5        None                NaN          NaN
# 32000203  200948    87304     4.5        None                NaN          NaN
#
# [32000204 rows x 6 columns]

# %%
df_ratings_with_diff_reviews[df_ratings_with_diff_reviews["review_text"].notna()]
# Out:
#           userId  movieId  rating  \
# 8              1      110     3.0
# 9              1      111     5.0
# 15             1      260     5.0
# 21             1      356     2.0
# 22             1      527     3.0
# ...          ...      ...     ...
# 31987956  200861   197711     2.5
# 31987959  200861   200540     1.5
# 31987968  200861   203222     0.5
# 31990207  200876   194951     0.5
# 31992876  200901    64997     4.0
#
#                                                 review_text  \
# 8          Mel versus history\nWhy is Braveheart regarde...
# 9          Disturbing, powerful, relevant, important\nA ...
# 15         A classics, phenomenal and arguably the best ...
# 21         Assault on intellectuals everywhere.\nPeople ...
# 22         Overrated!\nIt's not that Schindler's List is...
# ...                                                     ...
# 31987956   Worst Horror Movie in a long time.\nI conside...
# 31987959   Bad.\n<ul><li>Confusing. If you hadn't seen t...
# 31987968   Sticking to the original movie (1994)\nThe 20...
# 31990207   Direction and script broken. Zero understandi...
# 31992876   A modern and underrated sci-fi thriller.\nI'l...
#
#           review_raw_rating  rating_diff
# 8                       6.0          0.0
# 9                      10.0          0.0
# 15                     10.0          0.0
# 21                      4.0          0.0
# 22                      6.0          0.0
# ...                     ...          ...
# 31987956                1.0          2.0
# 31987959                1.0          1.0
# 31987968                1.0          0.0
# 31990207                1.0          0.0
# 31992876                8.0          0.0
#
# [573282 rows x 6 columns]

# %%
df_ratings_with_diff_reviews.to_csv("data/ratings_reviews_unique.csv", index=False)

# %% [markdown]
# In the end we have dataset with user id, movie id, rating and review text where applicable. Overall we have 573k reviews and 32m rows with ratings. There are also debug columns for review rating from the other source with reviews and scaled rating difference between rating and review rating. Next step is to obtain semantic score for available reviews and use them in our recommendation system
